# %%
import numpy as np
import pandas as pd
import nltk


df=pd.read_csv("indianrecipes.csv")

df
# Out:
#      Unnamed: 0  RecipeId            Name  CookTime  PrepTime  TotalTime  ...  \
# 0            71       159   Chicken Curry      42.0      65.0      107.0  ...
# 1          1171      3361    French Toast       0.0       0.0        0.0  ...
# 2          1976      5037            Roti       0.0       0.0        0.0  ...
# 3          3025      7837     Onion Rings       0.0       0.0        0.0  ...
# 4          3790      8988  Butter Chicken      20.0      15.0       35.0  ...
# 5          4084      9437            Chai      23.0      10.0       33.0  ...
# 6          7744     14886    Palak Paneer      30.0      30.0       60.0  ...
# 7          9290     17109   Chicken Curry      30.0      10.0       40.0  ...
# 8          9954     18084     Onion Rings      15.0      15.0       30.0  ...
# 9         13030     22525  Butter Chicken      45.0      15.0       60.0  ...
# 10        14827     25099   Chicken Curry      25.0      15.0       40.0  ...
# ...
